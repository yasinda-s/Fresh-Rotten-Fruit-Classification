# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/fruitdetection_yolo
# Out:
# /content/drive/MyDrive/Colab Notebooks/fruitdetection_yolo

# %%
#%ls

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 2022-6-26 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %%
#%ls

# %%
# Train YOLOv5s on COCO128 for 300 epochs
#!python train.py --img 640 --batch 16 --epochs 300 --data custom.yaml --weights yolov5s.pt --cache

# %%
#%ls
# Out:
# CONTRIBUTING.md  export.py   __pycache__/      setup.cfg       val.py
# custom.yaml      hubconf.py  README.md         train.py        yolov5s.pt
# data/            LICENSE     requirements.txt  tutorial.ipynb
# detect.py        models/     runs/             utils/

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source test.png
# Out:
# detect: weights=['runs/train/exp/weights/last.pt'], source=test.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2022-6-26 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/Colab Notebooks/fruitdetection_yolo/yolov5/test.png: 608x640 1 rotten, Done. (0.021s)
# Speed: 0.8ms pre-process, 21.4ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source test3.png
# Out:
# detect: weights=['runs/train/exp/weights/last.pt'], source=test3.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2022-6-26 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/Colab Notebooks/fruitdetection_yolo/yolov5/test3.png: 352x640 5 rottens, Done. (0.022s)
# Speed: 0.7ms pre-process, 22.5ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source test4.jpg
# Out:
# detect: weights=['runs/train/exp/weights/last.pt'], source=test4.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2022-6-26 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/Colab Notebooks/fruitdetection_yolo/yolov5/test4.jpg: 640x640 1 fresh, Done. (0.013s)
# Speed: 0.8ms pre-process, 13.5ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source test5.jpg
# Out:
# detect: weights=['runs/train/exp/weights/last.pt'], source=test5.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2022-6-26 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/Colab Notebooks/fruitdetection_yolo/yolov5/test5.jpg: 448x640 1 rotten, 1 fresh, Done. (0.020s)
# Speed: 0.7ms pre-process, 20.1ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6
