# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/fruitdetection_yolo
# Out:
# /content/drive/MyDrive/Colab Notebooks/fruitdetection_yolo

# %%
# %cd yolov5

import matplotlib.pyplot as plt
import numpy as np
import cv2
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 2022-6-26 Python-3.7.13 torch-1.11.0+cu113 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.4/107.7 GB disk)

# %%
#load model
model = torch.hub.load('ultralytics/yolov5', 'custom', 'last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2022-6-26 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients
# Adding AutoShape...

# %%
img = "/content/drive/MyDrive/Colab Notebooks/fruitdetection_yolo/yolov5/test.png"
results = model(img)
results.print()
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
# Out:
# image 1/1: 338x370 1 rotten
# Speed: 56.6ms pre-process, 837.9ms inference, 9.3ms NMS per image at shape (1, 3, 608, 640)

# %%
import os
def test_img(filename):
  # %matplotlib inline
  results = model("/content/drive/MyDrive/Colab Notebooks/fruitdetection_yolo/yolov5/test images/"+filename)
  results.print()
  plt.imshow(np.squeeze(results.render()))

# %%
for filename in os.listdir("/content/drive/MyDrive/Colab Notebooks/fruitdetection_yolo/yolov5/test images"):
  test_img(filename)
  plt.pause(0.0001)
# Out:
# image 1/1: 364x319 1 fresh
# Speed: 15.1ms pre-process, 374.4ms inference, 1.2ms NMS per image at shape (1, 3, 640, 576)
# image 1/1: 1000x1000 1 fresh
# Speed: 46.9ms pre-process, 415.5ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 800x800 1 fresh
# Speed: 27.6ms pre-process, 421.4ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# image 1/1: 769x1024 1 rotten
# Speed: 27.1ms pre-process, 356.6ms inference, 1.7ms NMS per image at shape (1, 3, 512, 640)
# image 1/1: 592x889 8 rottens
# Speed: 27.3ms pre-process, 305.1ms inference, 1.4ms NMS per image at shape (1, 3, 448, 640)
# image 1/1: 1703x2560 20 rottens, 3 freshs
# Speed: 112.0ms pre-process, 294.0ms inference, 1.4ms NMS per image at shape (1, 3, 448, 640)
# image 1/1: 551x800 3 rottens
# Speed: 26.6ms pre-process, 284.4ms inference, 1.1ms NMS per image at shape (1, 3, 448, 640)
# image 1/1: 883x800 1 rotten
# ...
